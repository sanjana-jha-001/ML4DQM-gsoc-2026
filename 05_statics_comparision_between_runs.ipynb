# %%
import numpy as np
from tensorflow.keras import layers, models

# %%
data_run1 = np.load("C:/Users/Sanjana/Downloads/Run355456_Dataset_jqkne.npy")
data_run2 = np.load("C:/Users/Sanjana/Downloads/Run357479_Dataset_iodic.npy")

print("Run1 shape:", data_run1.shape)
print("Run2 shape:", data_run2.shape)
print("Run1 dtype:", data_run1.dtype)
print("Run2 dtype:", data_run2.dtype)
# Out:
# Run1 shape: (10000, 64, 72)
# Run2 shape: (10000, 64, 72)
# Run1 dtype: float64
# Run2 dtype: float64

# %%
print("Run A stats:")
print("Mean:", np.mean(data_run1))
print("Std:", np.std(data_run1))
print("Min:", np.min(data_run1))
print("Max:", np.max(data_run1))
# Out:
# Run A stats:
# Mean: 157.1422515113881
# Std: 364.3050414058999
# Min: 0.0
# Max: 1564.944737802157

# %%
print("\nRun B stats:")
print("Mean:", np.mean(data_run2))
print("Std:", np.std(data_run1))
print("Min:", np.min(data_run1))
print("Max:", np.max(data_run1))
# Out:
# Run B stats:
# Mean: 181.0825829820982
# Std: 364.3050414058999
# Min: 0.0
# Max: 1564.944737802157

# %%
import matplotlib.pyplot as plt

# %%
mean_A = np.mean(data_run1, axis=0)
mean_B = np.mean(data_run2, axis=0)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.title("Mean Run A")
plt.imshow(mean_A, cmap='viridis')
plt.colorbar()

plt.subplot(1,2,2)
plt.title("Mean Run B")
plt.imshow(mean_B, cmap='viridis')
plt.colorbar()

plt.show()
